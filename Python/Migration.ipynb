# %% [markdown]
# # Data Migration

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import xlrd
import pyodbc
from datetime import datetime
from IPython.display import display, HTML
from sqlalchemy import create_engine
import sqlalchemy

# %%
#pyodbc
try:
    conn = pyodbc.connect('DRIVER={SQL Server};SERVER=40.121.0.247;PORT=1433;DATABASE=LeadIntelligencetest;uid=mysights;pwd=zXcasdqwe123')
    crsr = conn.cursor()
    print('DB Connection Success !')
except Exception as e:
    print ("Error: " + str(e))
    
#sqlalchemy sqlsrv pyodbc SQL+Server+Native+Client+11.0
try:
    engine = create_engine('mssql+pyodbc://mysights:zXcasdqwe123@40.121.0.247:1433/LeadIntelligencetest?driver=SQL+Server')
    print('Engine Connection Success !')
except Exception as f:
    print ("Error: " + str(f))
# Out:
# DB Connection Success !
# Engine Connection Success !

# %%
stripColumn = ['NoFaktur',
               'Kota',
               'KodePos',
               'Provinsi',
               'NoKTP',
               'NoHP',]

tglColumn   = ['TanggalCetak',
               'TanggalMohon',
               'TanggalLahir',]

blankColumn = ['Agama',
               'FinanceCompany',
               'UangMuka',
               'TenorTahun',
               'Email',
               'JenisKelamin',
               'Pekerjaan',
               'Pengeluaran',
               'Pendidikan',
               'PIC',
               'MerkSebelumnya',
               'JenisSebelumnya',
               'Fungsi',
               'Pemakai',
               'StatusRumah',
               'Facebook',
               'Twitter',
               'Instagram',
               'Youtube',
               'Hobi',
               'Remark',
              ]

selectColumn = ['NoFaktur',
                'NoKTP',
                'NoHP',
                'Kota',
                'KodeDealer',
                'KodePos',
                'Provinsi',
                'TanggalCetak',
                'TanggalMohon',
                'TanggalLahir',
                'Nama',
                'NoRangka',
                'KodeMesin',
                'NoMesin',
                'TipeMotor',
                'Warna',
                'JenisKelamin',
                'Alamat',
                'Kelurahan',
                'Kecamatan',
                'Email',
                'CashCredit',
                'FinanceCompany',
                'UangMuka',
                'UangMukaAktual',
                'Cicilan',
                'TenorBulan',
                'TenorTahun',
                'Agama',
                'Pekerjaan',
                'Pengeluaran',
                'Pendidikan',
                'StatusHP',
                'NoTelp',
                'NoHP',
                'Umur',
                'RangeUmur',
                'KebersediaanDihubungi',
                'Jenis3',
                'Jenis6',
                'MerkSebelumnya',
                'JenisSebelumnya',
                'Fungsi',
                'Pemakai',
                'SalesPerson',
                'TanggalVerifikasi',
                'StatusVerifikasi',
                'Hobi',
                'Facebook',
                'Twitter',
                'Instagram',
                'Youtube',
                'PIC',
                'StatusRumah',
                'TipeATPM',
                'TipeVarPlus',
                'NoCustomer',
                'ROType',
                'ROData',
                'NoAnggota',
                'Region',
                'Remark',
                'JenisSales',                
                ]

delColumn = ['Kode Msn',
             'No. Mesin2',
             'No. KTP',
             'alamat3',
             'Kel4',
             'Kec 5',
             'Kota/Kab',
             'Kode Pos6',
             'Propinsi',
             'Verify Flag',
             'Buyer Name',
             'Buyer Address',
             'Buyer Kelurahan',
             'Buyer Kecamatan',
             'Flag Update No. HP',
             'Flag Update Tgl Lahir',
             'Flag Update Agama',
             'Flag Update Pekerjaan',
             'Flag Update Cash/Credit',
             'Flag Update Fin',
             'Emails',
             'ReferallID',
             'Flag DP',
             'Flag Tenor',
             'Flag Cicilan',
             'Flag Email',
             'Flag Hobi',
             'Flag Keterangan',
             'TanggalVerifikasi']

# %%
df = pd.read_excel(r'C:\Users\Najib\Documents\AGIT\Customer Insight\Data\AHM\1Januari2018.xlsx')

df = df.rename(columns={'No. Faktur' : 'NoFaktur',
                        'KTP No' : 'NoKTP',
                        'Kode Kota' : 'Kota',
                        'Kode Dealer' : 'KodeDealer',
                        'Kode Pos' : 'KodePos',
                        'Kode Prov' : 'Provinsi',
                        'Tgl Cetak' : 'TanggalCetak',
                        'Tgl Mohon' : 'TanggalMohon',
                        'Tgl Lahir' : 'TanggalLahir',
                        'No. Rangka' : 'NoRangka',
                        'Kode Mesin' : 'KodeMesin',
                        'No. Mesin' : 'NoMesin',
                        'TIPE' : 'TipeMotor',
                        'Gender' : 'JenisKelamin',
                        'Kel' : 'Kelurahan',
                        'Kec' : 'Kecamatan',
                        'Cash Credit' : 'CashCredit',
                        'Finance Company' : 'FinanceCompany',
                        'Down Payment' : 'UangMuka',
                        'DP Aktual' : 'UangMukaAktual',
                        'Tenor Bulan' : 'TenorBulan',
                        'Tenor Tahun' : 'TenorTahun',
                        'Status Handphone' : 'StatusHP',
                        'No. Telp' : 'NoTelp',
                        'No.HP' : 'NoHP',
                        'Range Umur' : 'RangeUmur',
                        'diHubungi' : 'KebersediaanDihubungi',
                        '3JENIS' : 'Jenis3',
                        '6JENIS' : 'Jenis6',
                        'Merk' : 'MerkSebelumnya',
                        'Jenis' : 'JenisSebelumnya',
                        'SalesPerson' : 'SalesPerson',
                        'Verify Date' : 'TanggalVerifikasi',
                        'Status Verifikasi' : 'StatusVerifikasi',
                        'Status Rumah' : 'StatusRumah',
                        'Tipe ATPM' : 'TipeATPM',
                        'Tipe Var Plus' : 'TipeVarPlus',
                        'Cust No.' : 'NoCustomer',
                        'RO Type' : 'ROType',
                        'RO Data' : 'ROData',
                        'Member No.' : 'NoAnggota',
                        'Jenis Sales' : 'JenisSales',
                        'REGION' : 'Region'
                        })

#cleansing (')
for i in stripColumn:
    df[i] = df[i].apply(lambda x: x.strip("'"))

#converting string to date
for j in tglColumn:
    df[j] = df[j].apply(lambda x: x.strip("'"))
    df[j] = df[j].apply(lambda x: datetime.strptime(x, '%d%m%Y'))

#converting N to NaN/Null
for k in blankColumn:
    df[k] = df[k].replace({'N' : np.NaN})

#deleting unused column
for l in delColumn:
    del df[l]
    
#data = []

#data = df[selectColumn]
#display(HTML(df.to_html()))

#Exporting Data Frames to Excel
#df.to_excel(r'C:\Users\Najib\Documents\AGIT\Customer Insight\Data\AHM\Import.xlsx', sheet_name = 'Sheet1', index = False)

# %%
#df['CustomerID'] = df['Nama']
df['DealerID'] = '5'
df['RowStatus'] = 1
df['CreatedBy'] = 'DSSCI5'
df['CreatedDate'] = datetime.now()

display(df.head(100))
#print(datetime.now())
#print(df['CustomerID'])
#del data['CustomerID']

#print(df['CreatedDate'])

#df.shape

#cols = df.columns.tolist()
# Out:
#          NoFaktur        NoRangka KodeMesin  No. Mesi TanggalCetak  \
# 0   NDS /030741/Q  JBG111HK204959     JBG1E   1201462   2018-01-04
# 1   NDS /030744/Q  JBG114HK204955     JBG1E   1201464   2018-01-04
# 2   NDS /030802/Q  JBG110HK205164     JBG1E   1201811   2018-01-15
# 3   NDS /030785/Q  JBG114HK205278     JBG1E   1201938   2018-01-10
# 4   NDS /030800/Q  JBG119HK205289     JBG1E   1201952   2018-01-05
# 5   NDS /032662/Q  JBG117HK205405     JBG1E   1201954   2018-01-20
# 6   NDS /032777/Q  JBG113HK205529     JBG1E   1202013   2018-01-10
# 7   NDS /032779/Q  JBG114HK205507     JBG1E   1202134   2018-01-24
# 8   NDS /032788/Q  JBG118HK205509     JBG1E   1202136   2018-01-20
# 9   NDS /033101/Q  JBG115HK205595     JBG1E   1202283   2018-01-06
# 10  NDS /033096/Q  JBG114HK205703     JBG1E   1202313   2018-01-03
# 11  NDS /033104/Q  JBG116HK205704     JBG1E   1202316   2018-01-25
# 12  NDS /033082/Q  JBG110HK205598     JBG1E   1202332   2018-01-26
# ...

# %%
def sqlcol(dfparam):    

    dtypedict = {}
    for i,j in zip(dfparam.columns, dfparam.dtypes):
        if "object" in str(j):
            dtypedict.update({i: sqlalchemy.types.NVARCHAR(length=255)})

        if "datetime" in str(j):
            dtypedict.update({i: sqlalchemy.types.DateTime()})

        if "float" in str(j):
            dtypedict.update({i: sqlalchemy.types.Float(precision=3, asdecimal=True)})

        if "int" in str(j):
            dtypedict.update({i: sqlalchemy.types.INT()})

    return dtypedict

outputdict = sqlcol(df)
#print(outputdict)

#Insert Into Database
#df.to_sql(name = 'TB_R_SO_TEST', con = engine, index = False, if_exists = 'append', chunksize = 50)

#Exporting DataFrame to CSV File
df.to_csv(r'C:\Users\Najib\Documents\AGIT\Customer Insight\Data\AHM\Import.csv', sep='|', header = True, quotechar='"', encoding='utf-8', index=False, line_terminator = '\n')
 
#df.dtypes

# %%
sql = """ BULK INSERT TB_R_SO_TEST 
          FROM 'D:\\agit\\Import.csv' 
          WITH (
                  FIRSTROW=2,
                  FIELDTERMINATOR='|',
                  ROWTERMINATOR='\\n');
      """

crsr.execute(sql)
conn.commit()
crsr.close()
conn.close()

print('Upload Succeeded !')
#os.remove(r'C:\Users\Najib\Documents\AGIT\Customer Insight\Data\AHM\Import.csv')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-65a8a8854e7a> in <module>()
#       7       """
#       8
# ----> 9 crsr.execute(sql)
#      10 conn.commit()
#      11 crsr.close()
#
# ProgrammingError: ('42000', '[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Cannot bulk load because the file "D:\\agit\\Import.csv" could not be opened. Operating system error code 3(The system cannot find the path specified.). (4861) (SQLExecDirectW)')
